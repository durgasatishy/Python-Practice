# %% [markdown]
# # #To test/print given number is even or odd !!

# %%
num = input("please enter the number and i wil tell you the number is even or odd!!")
num = int(num)
if num%2==0:
    print(f"\nthe number entered {num} is even !!")
else :print(f"\n{num} is an odd number!!")
# Out:
# please enter the number and i wil tell you the number is even or odd!!10
#
# the number entered 10 is even !!

# %%
num = input("please enter the number and i wil tell you the number is even or odd!!")
num = int(num)
if num % 2 == 0:
    print(f"\nthe number entered {num} is even !!")
else :print(f"\n{num} is an odd number!!")
# Out:
# please enter the number and i wil tell you the number is even or odd!!13
#
# 13 is an odd number!!

# %% [markdown]
# # # Introduction to While loops:
# As long as certain condition id MET OR TRUE the program will run.
#
# When ever we used TRUE , we need to break the loop.

# %%
cur_num = 1
while cur_num <= 5:
    print(cur_num)
    cur_num += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(cur_num)
# Out:
# 6

# %%
print(cur_num)
# Out:
# 6

# %%
current_num = 2
while current_num <= 25:
    print(current_num)
    current_num+=3
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23

# %%
current_num     =     2
while current_num <=   25:
    print(current_num)
    current_num     +=          3
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23

# %% [markdown]
# # Letting the user when to quit:

# %%
prompt = "\nTell me something, i will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program."
message = ""

while message != 'quit':
    message    = input(prompt)
    print(message)
# Out:
# Tell me something, i will repeat it back to you:
# Enter 'quit' to end the program.hi
# hi
#
# Tell me something, i will repeat it back to you:
# Enter 'quit' to end the program.hello
# hello
#
# Tell me something, i will repeat it back to you:
# Enter 'quit' to end the program.quit
# quit

# %%
print(prompt)
# Out:
# Tell me something, i will repeat it back to you:
# Enter 'quit' to end the program.

# %%
prompt = "Tell me something and i will repeat it for you: \nEnter 'quit' to end. "

# %%
print(prompt)
# Out:
# Tell me something and i will repeat it for you:
# Enter 'quit' to end.

# %%
message = ''

# %%
print(message)

# %%
while message != 'quit':
    message = input(prompt)
    print(message)
# Out:
# Tell me something and i will repeat it for you:
# Enter 'quit' to end. how r u
# how r u
# Tell me something and i will repeat it for you:
# Enter 'quit' to end. im good
# im good
# Tell me something and i will repeat it for you:
# Enter 'quit' to end. quit
# quit

# %%
# Above statements prompting will repeat untill user enter quit on text box.

# %%
city = ''

# %%
prompt = "\nEnter the name of the you have visited"
prompt+="\nEnter quit to end program: "
city == ''
while True:
    city == input(prompt)
    if city == "quit":
        break
        else:
        print(f"I did like to visit {city.title()} again")
# Out:
#   File "<ipython-input-11-af75eb34cc8f>", line 8
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
prompt = "\nEnter the name of the you have visited: \nEnter quit to end program: "
city = ''
while True:
    city = input(prompt)
    print(f"hi , i would like to visit {city.title()}")
    if city == 'quit':
        break
# Out:
# Enter the name of the you have visited:
# Enter quit to end program: london
# hi , i would like to visit London
#
# Enter the name of the you have visited:
# Enter quit to end program: hyd
# hi , i would like to visit Hyd
#
# Enter the name of the you have visited:
# Enter quit to end program: bang
# hi , i would like to visit Bang
#
# Enter the name of the you have visited:
# Enter quit to end program: quit
# hi , i would like to visit Quit

# %%
prompt = "\nEnter the name of the you have visited: \nEnter quit to end program: "
while True:
    city = input(prompt)
    if city != 'quit':
        print(f"hi , i would like to visit {city.title()}")
        else:
            break
# Out:
#   File "<ipython-input-6-948a3ee54e96>", line 6
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
number = 0

for number in range(10):
    if number == 5:
        break    # break here

    print('Number is ' + str(number))

print('Out of loop')
# Out:
# Number is 0
# Number is 1
# Number is 2
# Number is 3
# Number is 4
# Out of loop

# %%
number = 0

for number in range(10):
    if number == 5:
        continue    # continue here

    print('Number is ' + str(number))

print('Out of loop')
# Out:
# Number is 0
# Number is 1
# Number is 2
# Number is 3
# Number is 4
# Number is 6
# Number is 7
# Number is 8
# Number is 9
# Out of loop

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    continue
  i += 1
# Out:
# 1
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
prompt = "\nEnter the name of the you have visited: \nEnter quit to end program: "
city = ''
while True:
    city = input(prompt)
    print(f"hi , i would like to visit {city.title()}")
    if city == 'quit':
        break
# Out:
# Enter the name of the you have visited:
# Enter quit to end program: lonodn
# hi , i would like to visit Lonodn
#
# Enter the name of the you have visited:
# Enter quit to end program: ny
# hi , i would like to visit Ny
#
# Enter the name of the you have visited:
# Enter quit to end program: delhi
# hi , i would like to visit Delhi
#
# Enter the name of the you have visited:
# Enter quit to end program: Quit
# hi , i would like to visit Quit
#
# Enter the name of the you have visited:
# Enter quit to end program: quit
# hi , i would like to visit Quit
